# %%
import tensorflow as tf
import pandas
import sklearn
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Dense,Flatten, Rescaling, Dropout,BatchNormalization,Conv2D,MaxPooling2D
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dropout

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()

# %%
def print_Examples(x_train, y_train):
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(x_train[i])
        plt.title("The label is " + str(y_train[i]))
        plt.axis("off")

# %%
# def model(input_shape, num_classes,x_train, y_train,x_test,y_test, epochs):
#     model = Sequential([ 
#         layers.Rescaling(1./255, input_shape=input_shape), 
#         layers.Conv2D(32, 3, padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.MaxPooling2D(pool_size=(2,2)), 
#         layers.Dropout(0.25), 
#         layers.Conv2D(64, 3, padding='same', activation='relu'),
#         layers.BatchNormalization(),
#         layers.MaxPooling2D(pool_size=(2,2)), 
#         layers.Dropout(0.25), 
#         layers.Flatten(), 
#         layers.Dense(512, activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(0.5), 
#         layers.Dense(128, activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dense(64, activation='relu'),
#         layers.BatchNormalization(),
#         layers.Dropout(0.5), 
#         layers.Dense(num_classes, activation="softmax") 
#     ]) 
    
#     model.compile(optimizer='adam', 
#                 loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
#                 metrics=['accuracy']) 

#     early_stopping = EarlyStopping(monitor='val_loss', patience=5)
#     checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
#     model.summary() 
    
#     hist = model.fit(x_train,
#     y_train,
#     batch_size=32,
#     epochs=epochs,
#     validation_data=(x_test, y_test),
#     callbacks=[early_stopping,checkpoint])
#     return model,hist

# %%
def model(input_shape, num_classes,x_train, y_train,x_test,y_test, epochs):
    model = Sequential([
        Rescaling(1./255, input_shape=(28, 28, 1)),
        Conv2D(32, 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(0.25),
        Conv2D(64, 3, padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(0.25),
        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])
    
    model.compile(optimizer='adam', 
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                metrics=['accuracy']) 

    early_stopping = EarlyStopping(monitor='val_loss', patience=5)
    checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    model.summary() 
    
    hist = model.fit(x_train,
    y_train,
    batch_size=32,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping,checkpoint])
    return model,hist

# %%
print_Examples(x_train, y_train)

# %%
epochs=30
model,hist = model((28,28,1), 10,x_train,y_train,x_test, y_test,epochs)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 28, 28, 1)         0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        320
#
#  batch_normalization_5 (Bat  (None, 28, 28, 32)        128
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        18496
#
#  batch_normalization_6 (Bat  (None, 14, 14, 64)        256
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 512)               1606144
#
#  batch_normalization_7 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 128)               65664
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1702730 (6.50 MB)
# Trainable params: 1701130 (6.49 MB)
# Non-trainable params: 1600 (6.25 KB)
# _________________________________________________________________
# Epoch 1/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.4090 - accuracy: 0.8767
# Epoch 1: val_accuracy improved from -inf to 0.98130, saving model to best_model.h5
# 1875/1875 [==============================] - 21s 9ms/step - loss: 0.4090 - accuracy: 0.8767 - val_loss: 0.0598 - val_accuracy: 0.9813
# Epoch 2/30
#    5/1875 [..............................] - ETA: 24s - loss: 0.2975 - accuracy: 0.9312
# /home/himanshu/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1588 - accuracy: 0.9557
# Epoch 2: val_accuracy improved from 0.98130 to 0.98760, saving model to best_model.h5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1587 - accuracy: 0.9557 - val_loss: 0.0373 - val_accuracy: 0.9876
# Epoch 3/30
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9660
# Epoch 3: val_accuracy did not improve from 0.98760
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1264 - accuracy: 0.9659 - val_loss: 0.0413 - val_accuracy: 0.9869
# Epoch 4/30
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9710
# Epoch 4: val_accuracy improved from 0.98760 to 0.98920, saving model to best_model.h5
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1065 - accuracy: 0.9710 - val_loss: 0.0353 - val_accuracy: 0.9892
# Epoch 5/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9754
# Epoch 5: val_accuracy did not improve from 0.98920
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0901 - accuracy: 0.9754 - val_loss: 0.0379 - val_accuracy: 0.9882
# Epoch 6/30
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9773
# Epoch 6: val_accuracy improved from 0.98920 to 0.99190, saving model to best_model.h5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0890 - accuracy: 0.9773 - val_loss: 0.0246 - val_accuracy: 0.9919
# Epoch 7/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9782
# Epoch 7: val_accuracy did not improve from 0.99190
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0795 - accuracy: 0.9783 - val_loss: 0.0287 - val_accuracy: 0.9908
# Epoch 8/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9805
# Epoch 8: val_accuracy did not improve from 0.99190
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0716 - accuracy: 0.9805 - val_loss: 0.0313 - val_accuracy: 0.9911
# Epoch 9/30
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9819
# Epoch 9: val_accuracy improved from 0.99190 to 0.99260, saving model to best_model.h5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0659 - accuracy: 0.9819 - val_loss: 0.0280 - val_accuracy: 0.9926
# Epoch 10/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9825
# Epoch 10: val_accuracy did not improve from 0.99260
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0635 - accuracy: 0.9825 - val_loss: 0.0243 - val_accuracy: 0.9926
# Epoch 11/30
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9842
# Epoch 11: val_accuracy improved from 0.99260 to 0.99280, saving model to best_model.h5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0601 - accuracy: 0.9842 - val_loss: 0.0250 - val_accuracy: 0.9928
# Epoch 12/30
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9845
# Epoch 12: val_accuracy improved from 0.99280 to 0.99390, saving model to best_model.h5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0592 - accuracy: 0.9845 - val_loss: 0.0233 - val_accuracy: 0.9939
# Epoch 13/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9851
# Epoch 13: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0543 - accuracy: 0.9851 - val_loss: 0.0242 - val_accuracy: 0.9929
# Epoch 14/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9864
# Epoch 14: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0509 - accuracy: 0.9864 - val_loss: 0.0216 - val_accuracy: 0.9933
# Epoch 15/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9854
# Epoch 15: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0546 - accuracy: 0.9854 - val_loss: 0.0276 - val_accuracy: 0.9928
# Epoch 16/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9871
# Epoch 16: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0487 - accuracy: 0.9871 - val_loss: 0.0257 - val_accuracy: 0.9929
# Epoch 17/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9879
# Epoch 17: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0457 - accuracy: 0.9879 - val_loss: 0.0262 - val_accuracy: 0.9935
# Epoch 18/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0449 - accuracy: 0.9880
# Epoch 18: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0449 - accuracy: 0.9880 - val_loss: 0.0310 - val_accuracy: 0.9907
# Epoch 19/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9885
# Epoch 19: val_accuracy did not improve from 0.99390
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0435 - accuracy: 0.9885 - val_loss: 0.0246 - val_accuracy: 0.9932

# %%
#Accuracy 
acc = hist.history['accuracy'] 
val_acc = hist.history['val_accuracy'] 

#loss 

loss = hist.history['loss'] 
val_loss = hist.history['val_loss'] 

#epochs 
epochs_range = range(len(acc))

#Plotting graphs 
plt.figure(figsize=(16, 8)) 
plt.subplot(1, 2, 1) 
plt.plot(epochs_range, acc, label='Training Accuracy') 
plt.plot(epochs_range, val_acc, label='Validation Accuracy') 
plt.legend(loc='lower right') 
plt.title('Training and Validation Accuracy') 

plt.subplot(1, 2, 2) 
plt.plot(epochs_range, loss, label='Training Loss') 
plt.plot(epochs_range, val_loss, label='Validation Loss') 
plt.legend(loc='upper right') 
plt.title('Training and Validation Loss') 
plt.show()

# %%
results = model.evaluate(x_test, y_test, batch_size=128)
results[1]
# Out:
# 79/79 [==============================] - 2s 17ms/step - loss: 0.0246 - accuracy: 0.9932
# 0.9932000041007996

# %%
model.save(f'model{results[1]}.h5',overwrite=True)

# %%
import os

# Load the saved model
model = tf.keras.models.load_model('best_model.h5')

# Evaluate the model to get the validation accuracy
val_loss, val_acc = model.evaluate(x_test, y_test)

# Rename the model file
os.rename('best_model.h5', f'model{val_acc}.h5')

# model.summary()
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9939
