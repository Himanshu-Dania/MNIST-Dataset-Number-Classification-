# %%
import tensorflow as tf
import pandas
import sklearn
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.layers import Dropout

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()

# %%
def print_Examples(x_train, y_train):
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(x_train[i])
        plt.title("The label is " + str(y_train[i]))
        plt.axis("off")

# %%
def model(input_shape, num_classes,x_train, y_train,x_test,y_test, epochs):
    model = Sequential([ 
        layers.Rescaling(1./255, input_shape=input_shape), 
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)), 
        layers.Dropout(0.25), # Dropout layer
        layers.Conv2D(64, 1, padding='same', activation='relu'),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)), 
        layers.Dropout(0.25), # Dropout layer
        layers.Conv2D(64, 1, padding='same', activation='relu'), # 1x1 Convolution
        layers.Flatten(), 
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5), # Dropout layer
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5), # Dropout layer
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax") 
    ]) 

    model.compile(optimizer='adam', 
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                metrics=['accuracy']) 

    early_stopping = EarlyStopping(monitor='val_loss', patience=5)
    checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    model.summary() 
    
    hist = model.fit(x_train,
    y_train,
    batch_size=32,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping,checkpoint])
    
    
    return model,hist

# %%
print_Examples(x_train, y_train)

# %%
epochs=30
model,hist = model((28,28,1), 10,x_train,y_train,x_test, y_test,epochs)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 28, 28, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)        320
#
#  batch_normalization_5 (Bat  (None, 28, 28, 32)        128
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        2112
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 64)        36928
#
#  batch_normalization_6 (Bat  (None, 14, 14, 64)        256
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 64)          4160
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 512)               1606144
#
#  batch_normalization_7 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 128)               65664
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  batch_normalization_9 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1736586 (6.62 MB)
# Trainable params: 1734858 (6.62 MB)
# Non-trainable params: 1728 (6.75 KB)
# _________________________________________________________________
# Epoch 1/30
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.4008 - accuracy: 0.8793
# Epoch 1: val_accuracy improved from -inf to 0.98320, saving model to best_model.h5
# 1875/1875 [==============================] - 25s 12ms/step - loss: 0.4001 - accuracy: 0.8796 - val_loss: 0.0568 - val_accuracy: 0.9832
# Epoch 2/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1486 - accuracy: 0.9575
# Epoch 2: val_accuracy improved from 0.98320 to 0.98530, saving model to best_model.h5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.1484 - accuracy: 0.9575 - val_loss: 0.0485 - val_accuracy: 0.9853
# Epoch 3/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9662
# Epoch 3: val_accuracy improved from 0.98530 to 0.98870, saving model to best_model.h5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.1203 - accuracy: 0.9662 - val_loss: 0.0372 - val_accuracy: 0.9887
# Epoch 4/30
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9709
# Epoch 4: val_accuracy did not improve from 0.98870
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.1034 - accuracy: 0.9709 - val_loss: 0.0576 - val_accuracy: 0.9826
# Epoch 5/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9759
# Epoch 5: val_accuracy improved from 0.98870 to 0.98950, saving model to best_model.h5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0869 - accuracy: 0.9759 - val_loss: 0.0307 - val_accuracy: 0.9895
# Epoch 6/30
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0815 - accuracy: 0.9774
# Epoch 6: val_accuracy improved from 0.98950 to 0.99040, saving model to best_model.h5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0815 - accuracy: 0.9773 - val_loss: 0.0326 - val_accuracy: 0.9904
# Epoch 7/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9802
# Epoch 7: val_accuracy improved from 0.99040 to 0.99140, saving model to best_model.h5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0709 - accuracy: 0.9802 - val_loss: 0.0282 - val_accuracy: 0.9914
# Epoch 8/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9809
# Epoch 8: val_accuracy improved from 0.99140 to 0.99290, saving model to best_model.h5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0690 - accuracy: 0.9809 - val_loss: 0.0246 - val_accuracy: 0.9929
# Epoch 9/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0608 - accuracy: 0.9831
# Epoch 9: val_accuracy did not improve from 0.99290
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.0609 - accuracy: 0.9831 - val_loss: 0.0240 - val_accuracy: 0.9927
# Epoch 10/30
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9836
# Epoch 10: val_accuracy improved from 0.99290 to 0.99450, saving model to best_model.h5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0584 - accuracy: 0.9836 - val_loss: 0.0206 - val_accuracy: 0.9945
# Epoch 11/30
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0570 - accuracy: 0.9843
# Epoch 11: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0570 - accuracy: 0.9843 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 12/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9859
# Epoch 12: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0516 - accuracy: 0.9859 - val_loss: 0.0231 - val_accuracy: 0.9929
# Epoch 13/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0478 - accuracy: 0.9864
# Epoch 13: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0478 - accuracy: 0.9864 - val_loss: 0.0224 - val_accuracy: 0.9930
# Epoch 14/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9870
# Epoch 14: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0468 - accuracy: 0.9870 - val_loss: 0.0204 - val_accuracy: 0.9935
# Epoch 15/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9871
# Epoch 15: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0454 - accuracy: 0.9871 - val_loss: 0.0223 - val_accuracy: 0.9937
# Epoch 16/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9881
# Epoch 16: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 0.0236 - val_accuracy: 0.9928
# Epoch 17/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9881
# Epoch 17: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0416 - accuracy: 0.9882 - val_loss: 0.0201 - val_accuracy: 0.9941
# Epoch 18/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9888
# Epoch 18: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0404 - accuracy: 0.9888 - val_loss: 0.0219 - val_accuracy: 0.9937
# Epoch 19/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9888
# Epoch 19: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0409 - accuracy: 0.9888 - val_loss: 0.0197 - val_accuracy: 0.9940
# Epoch 20/30
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9894
# Epoch 20: val_accuracy did not improve from 0.99450
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0375 - accuracy: 0.9894 - val_loss: 0.0218 - val_accuracy: 0.9935
# Epoch 21/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9892
# Epoch 21: val_accuracy improved from 0.99450 to 0.99470, saving model to best_model.h5
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0376 - accuracy: 0.9892 - val_loss: 0.0198 - val_accuracy: 0.9947
# Epoch 22/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9908
# Epoch 22: val_accuracy did not improve from 0.99470
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0336 - accuracy: 0.9908 - val_loss: 0.0226 - val_accuracy: 0.9945
# Epoch 23/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9907
# Epoch 23: val_accuracy did not improve from 0.99470
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0335 - accuracy: 0.9908 - val_loss: 0.0191 - val_accuracy: 0.9946
# Epoch 24/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9900
# Epoch 24: val_accuracy improved from 0.99470 to 0.99480, saving model to best_model.h5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0361 - accuracy: 0.9900 - val_loss: 0.0171 - val_accuracy: 0.9948
# Epoch 25/30
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9915
# Epoch 25: val_accuracy did not improve from 0.99480
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0311 - accuracy: 0.9915 - val_loss: 0.0237 - val_accuracy: 0.9939
# Epoch 26/30
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9909
# Epoch 26: val_accuracy did not improve from 0.99480
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0323 - accuracy: 0.9909 - val_loss: 0.0210 - val_accuracy: 0.9934
# Epoch 27/30
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9918
# Epoch 27: val_accuracy did not improve from 0.99480
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.0303 - accuracy: 0.9918 - val_loss: 0.0210 - val_accuracy: 0.9944
# Epoch 28/30
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0282 - accuracy: 0.9922
# Epoch 28: val_accuracy did not improve from 0.99480
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.0282 - accuracy: 0.9922 - val_loss: 0.0239 - val_accuracy: 0.9940
# Epoch 29/30
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9918
# Epoch 29: val_accuracy did not improve from 0.99480
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0300 - accuracy: 0.9918 - val_loss: 0.0213 - val_accuracy: 0.9940

# %%
#Accuracy 
acc = hist.history['accuracy'] 
val_acc = hist.history['val_accuracy'] 

#loss 

loss = hist.history['loss'] 
val_loss = hist.history['val_loss'] 

#epochs 
epochs_range = range(len(acc))

#Plotting graphs 
plt.figure(figsize=(16, 8)) 
plt.subplot(1, 2, 1) 
plt.plot(epochs_range, acc, label='Training Accuracy') 
plt.plot(epochs_range, val_acc, label='Validation Accuracy') 
plt.legend(loc='lower right') 
plt.title('Training and Validation Accuracy') 

plt.subplot(1, 2, 2) 
plt.plot(epochs_range, loss, label='Training Loss') 
plt.plot(epochs_range, val_loss, label='Validation Loss') 
plt.legend(loc='upper right') 
plt.title('Training and Validation Loss') 
plt.show()

# %%
results = model.evaluate(x_test, y_test, batch_size=128)
results[1]
# Out:
# 79/79 [==============================] - 1s 5ms/step - loss: 0.0213 - accuracy: 0.9940
# 0.9940000176429749

# %%
# model.save(f'model{results[1]}.h5',overwrite=True)

# %%
import os
import tensorflow as tf

# Load the saved model
model = tf.keras.models.load_model('best_model.h5')

# Evaluate the model to get the validation accuracy
val_loss, val_acc = model.evaluate(x_test, y_test)

# Rename the model file
os.rename('best_model.h5', f'model{val_acc}.h5')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0171 - accuracy: 0.9948
